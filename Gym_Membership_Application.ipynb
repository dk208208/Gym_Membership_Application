# %%
import time
class super_user:
    member_details = {}
    show_bmi = {}
    superuser_login_details = { }
    dict_of_regimen = {(0.0,18.5):
                      {"MONDAY":"Chest",
                       "TUESDAY":"Biceps",
                       "WEDNESDAY":"Rest" ,
                       "THURSDAY":"Back" ,
                       "FRIDAY":"Triceps",
                       "SATURDAY":"Rest" ,
                       "SUNDAY":"Rest"},
                      (18.6,25.0):
                      {"MONDAY":"Chest",
                       "TUESDAY":"Biceps",
                       "WEDNESDAY":"Cardio/Abs" ,
                       "THURSDAY":"Back" ,
                       "FRIDAY":"Triceps",
                       "SATURDAY":"Legs" ,
                       "SUNDAY":"Rest"},
                      (26.0,30.0):
                      {"MONDAY":"Chest",
                       "TUESDAY":"Biceps",
                       "WEDNESDAY":"Abs/Cardio" ,
                       "THURSDAY":"Back" ,
                       "FRIDAY":"Triceps",
                       "SATURDAY":"Legs" ,
                       "SUNDAY":"Cardio"},
                      (30.0,50.0):
                      {"MONDAY":"Chest",
                       "TUESDAY":"Biceps",
                       "WEDNESDAY":"Cardio" ,
                       "THURSDAY":"Back" ,
                       "FRIDAY":"Triceps",
                       "SATURDAY":"Cardio" ,
                       "SUNDAY":"Cardio"}
                     }
    
    def __init__(self):
        print("                                <<<   Welcome to Gym   >>>                                               \n")
        self.home()
      
    def super_login_portal(self):
        input_log = input("Press1. Sign-Up\nPress2. Sign-In\nPress0. Home")
        if input_log == "1":
            self.super_user_sign_up()
        elif input_log == "2":
            self.superuser_login()
        elif input_log == "0":
            self.home()
        else:
            print("Invalid Input!!!")
            self.super_login_portal()
        
    def super_user_sign_up(self):
        username =input("Create Your Username : ")
        if username not in super_user.superuser_login_details:
            password=input("Create Your Password : ")
            super_user.superuser_login_details[username] = password
            print("Sign-Up successfully")
        else:
            print("Username already exists... Try Again !!!")
            self.super_user_sign_up()
        self.super_login_portal()
        
    def superuser_login(self):
        username_log =input("Enter Your Username : ")
        if username_log in super_user.superuser_login_details:
            password_log=input("Enter Your Password : ")
            if super_user.superuser_login_details[username_log] == password_log:
                print("Log-in successfully")
                self.super_user_portal()
            else:
                print("Username or password does not match !!!")
                self.home()
        else:
            print("Username not found!!!")
            self.home()
        
    def create_regimen(self):
        local_dict = {}
        l1= [(9999,99999)]
        print("Enter The Range Of BMI")
        start =float(input("Enter Start Value"))
        end = float(input("Enter End Value"))
        for i in super_user.dict_of_regimen:
            l1.append(i)
            l1.sort()
        self.inp = (start,end)
        for i in range(len(l1)-1):
            if  l1[i][1] <= self.inp[0] and l1[i+1][0] >= self.inp[1]:
                super_user.dict_of_regimen[self.inp] = local_dict
                print("Enter details for regimen")
                inp_mon = input("For MONDAY")            
                local_dict["MONDAY"]=  inp_mon

                inp_mon = input("For TUESDAY")            
                local_dict["TUESDAY"]=  inp_mon

                inp_mon = input("For WEDNESDAY")            
                local_dict["WEDNESDAY"]=  inp_mon

                inp_mon = input("For THURSDAY")            
                local_dict["THURSDAY"]=  inp_mon

                inp_mon = input("For FRIDAY")            
                local_dict["FRIDAY"]=  inp_mon

                inp_mon = input("For SATURDAY")            
                local_dict["SATURDAY"]=  inp_mon

                inp_mon = input("For SUNDAY")            
                local_dict["SUNDAY"]=  inp_mon
                print("You have added successfully!!!")
        time.sleep(1)
        print(".\n")
        time.sleep(1)
        print(".\n")
        time.sleep(1)
        print(".\n")
        print("If don't show successfully message it means you have entered wrong range value!!!! ")
        input_ex = input("Press>>1. If you want to create regimen\nPress>>2. Back\n         ")
        if input_ex == "1":
            self.create_regimen()
        elif input_ex == "2":
            self.super_user_portal()
        self.super_user_portal()
        
    def view_regimen(self):
        for p_id, p_info in super_user.dict_of_regimen.items():
                print("\nBMI Range:", p_id)
                for key in p_info:
                    print(key + ':', p_info[key]) 
        time.sleep(1)
        print(".\n")
        time.sleep(1)
        print(".\n")
        time.sleep(1)
        print(".\n")                        
        self.super_user_portal()            
            
    def delete_regimen(self):
        input10 = float(input("Enter BMI Range\nStart Value"))
        input11 = float(input("\nEnd Value"))
        l12 = (input10,input11)
        if l12 in super_user.dict_of_regimen:
#             if  i == l12:
            del super_user.dict_of_regimen[l12]
#             else:
#                 print("Please! Enter Valid Range")
        else:
            print("Deletion successfully")
        self.super_user_portal()
            
    def update_regimen(self):
        input12 = float(input("Enter BMI Range\nStart Value : "))
        input13 = float(input("\nEnd Value : "))
        l13 = (input12,input13)
        if l13 in super_user.dict_of_regimen:
            input14 = input("Which Day You Want To Update\nPress>>1. MONDAY\nPress>>2. TUESDAY\nPress>>3. WEDNESDAY\nPress>>4. THURSDAY\nPress>>5. FRIDAY\nPress>>6. SATURDAY\nPress>>7. SUNDAY")
            if input14 == "1":
                monday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["MONDAY"] = monday
                print("Monday has been updated.")
            elif input14 == "2":
                tuesday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["TUESDAY"] = tuesday
                print("Tuesday has been updated.")
            elif input14 == "3":
                wednesday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["WEDNESDAY"] = wednesday
                print("Wednesday has been updated.")
            elif input14 == "4":
                thursday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["THURSDAY"] = thursday
                print("Thursday has been updated.")
            elif input14 == "5":
                friday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["FRIDAY"] = friday
                print("Friday has been updated.")
            elif input14 == "6":
                saturday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["SATURDAY"] = saturday
                print("Saturday has been updated.")
            elif input14 == "7":
                sunday = input("Enter New Exercise : ")
                super_user.dict_of_regimen[l13]["SUNDAY"] = sunday
                print("Sunday has been updated.")
            else:
                print("Invalid Input!!!")
        self.super_user_portal()
                
    def member_creation(self):
        self.dict1 = {}
        self.Mobile_Number = input("Enter Your Mobile Number : ")
        if self.Mobile_Number not in super_user.member_details:
            self.full_name =input("Enter Your Full-Name : ")
            self.Age =input("Enter Your Age : ")
            self.Email = input("Enter Your Email : ")
            input3= input("Please ! Choose Duration You Want Membership\nPress>>1. 1 Month\nPress>>2. 3 Months\nPress>>3. 6 Months\nPress>>4. 12 Months\n")
            if input3 =="1":
                self.dict1["Membership Duration"] = 1
            elif input3 =="2":
                self.dict1["Membership Duration"] = 3
            elif input3 =="3":
                self.dict1["Membership Duration"] = 6
            elif input3 =="4":
                self.dict1["Membership Duration"] = 12
            else:
                print("\n Due to incorrect input you have to re-enter details\n")
                self.member_creation()
            super_user.member_details[self.Mobile_Number] = self.dict1
            self.dict1["Full Name"] = self.full_name
            self.dict1["Age"] = self.Age
            self.dict1["Email"] = self.Email
            self.dict1["Mobile Number"] = self.Mobile_Number
            self.error_maintainance()
        else:
            print("Mobile Number you have entered already registered !!!")
            self.super_user_portal()
            
    def error_maintainance(self):
        self.BMI = input("Press>>1. Enter Your BMI\nPress>>2. Know Your BMI\n")
        if self.BMI == "1":
            inp_bmi = float(input("Enter BMI : "))
            self.dict1["BMI"] = inp_bmi
            for i in super_user.dict_of_regimen:
                if i[0] <=inp_bmi<= i[1]:
                    self.dict1["Regimen"] = super_user.dict_of_regimen[i]
        elif self.BMI == "2":
            self.bmi_calculator()
        else:
            print("Invalid Input!!!")
            self.error_maintainance()
        self.super_user_portal()
    def bmi_calculator(self):
        self.height = int(input("Enter Your Height In Meter : "))
        self.weight = int(input("Enter Your Weight In Kilogram : "))
        self.BMI = self.height / ( self.weight* self.weight)
        for i in super_user.dict_of_regimen:
                if i[0] <=self.BMI<= i[1]:
                    self.dict1["BMI"] = self.BMI
                    self.dict1["Regimen"] = super_user.dict_of_regimen[i]
        
    def view_member_details(self):
        member_de = input("Enter member'mobile number : ")
        if member_de in super_user.member_details:
            print("...")
            time.sleep(1)
            ("...")
            time.sleep(1)
            print("Full Name : ", super_user.member_details[member_de]["Full Name"])
            print("Email : "  ,super_user.member_details[member_de]["Email"])
            print( "Age : ",  super_user.member_details[member_de]["Age"])
            print("Mobile Number : ", super_user.member_details[member_de]["Mobile Number"])
            print( "BMI : " ,super_user.member_details[member_de]["BMI"])
            print("Membership Duration : ",  super_user.member_details[member_de]["Membership Duration"])
            print("   <<Regimen>>  ")
            for i in super_user.member_details[member_de]["Regimen"].items():
                print(i[0]," : ",i[1])
            print("----------------------------------------------------------------------")
        else:
            print("Invalid Input or Member does not have membership !!!")
        self.super_user_portal()
        
        
    def delete_member(self):
        input5 = input("Enter Member's Mobile-Number You Want To Delete :  ")
        if input5 in super_user.member_details:
            del super_user.member_details[input5]
        else:
            input6 = input("Mobile no. invalid\nPress1. To Re-enter\nPress>>2. Back")
            if input6 == "1":
                self.delete_member()
            elif input6 == "2":
                self.super_user_portal()
        self.super_user_portal()

            
    def update_member(self):
        mob_input = input("Enter Member's Mobile number : ")
        if mob_input in super_user.member_details:
            input7 = input("What do you want to update \nPress>>1. Name\nPress>>2. Age\nPress>>3. BMI\nPress>>4. Email\nPress>>5. Membership Duration\nPress>>6. Back\nPress>>0. Home             ")
            if input7 == "1":
                in_name = input("Enter Name You Want To Update : ")
                super_user.member_details[mob_input]["Full Name"] = in_name
                print("Full Name has been updated.")
                self.update_member()
            elif input7 == "2":
                in_age = input("Enter Age You Want To Update : ")
                super_user.member_details[mob_input]["Age"] = in_age
                print("Age has been updated.")
                self.update_member()
            elif input7 == "3":
                in_bmi = input("Enter BMI You Want To Update : ")
                super_user.member_details[mob_input]["BMI"] = in_bmi
                print("BMI has been updated.")
                self.update_member()
            elif input7 == "4":
                in_email = input("Enter Email You Want To Update : ")
                super_user.member_details[mob_input]["Email"] = in_email
                print("Email has been updated.")
                self.update_member()
            elif input7 == "5":
                in_mem_dur= input("Please ! Choose Duration You Want Membership\nPress>>1. 1 Month\nPress>>2. 3 Months\nPress>>3. 6 Months\nPress>>4. 12 Months\n")
                if in_mem_dur =="1":
                    self.dict1["Membership Duration"] = 1
                elif in_mem_dur =="2":
                    self.dict1["Membership Duration"] = 3
                elif in_mem_dur =="3":
                    self.dict1["Membership Duration"] = 6
                elif in_mem_dur =="4":
                    self.dict1["Membership Duration"] = 12
                    super_user.member_details[mob_input]["Membership Duration"] = in_mem_dur
                    print("Membership Duration has been updated.")
                    self.update_member()
                else:
                    print("Invalid Input")
                    self.update_member()
            elif input7 == "6":
                self.super_user_portal()
            elif   input7 == "0":
                self.home()
            else:
                print("Invalid Input!!!")
                self.super_user_portal()
        
            
    def super_user_portal(self):
        print("--------------------------------------------------------------------------------------------------------\n")
        print("                                      <<<Superuser Portal>>>")
        input4 = input("Press>>1. Create Member\nPress>>2. View Member Details\nPress>>3. Delete Member\nPress>>4. Update Member\nPress>>5. Create Regimen\nPress>>6. View Regimen\nPress>>7. Delete Regimen\nPress>>8. Update Regimen\nPress>>0. Home              ")
        if input4 == "1":
            self.member_creation()
        elif input4 == "2":
            self.view_member_details()
        elif input4 == "3":
            self.delete_member()
        elif input4 == "4":
            self.update_member()
        elif input4 == "5":
            self.create_regimen()
        elif input4 == "6":
            self.view_regimen()
        elif input4 == "7":
            self.delete_regimen()
        elif input4 == "8":
            self.update_regimen()
        elif input4 == "0":
            self.home()
        else:
            print("Invalid Input!!!")
            self.super_user_portal()
        
    def home(self):
        print("                                   <<<  Home  >>>                               ")
        home_int = input("Press>>1. Superuser\nPress>>2. Member")
        if home_int=="1":
            self.super_login_portal()
        elif home_int == "2":
            self.member_portal()
        else:
            print("Invalid Input!!")
            self.home()
    
    def member_portal(self):
        print("                                 <<<   Member Portal   >>>                                          \n")
        input2 = input("Press>>1. My Regimen\nPress>>2. My Profile\nPress>>0. Home\n\n")
        if input2 == "1":
            in_mobile = input("Enter mobile no. : ")
            if in_mobile in super_user.member_details:
                for  i in super_user.member_details[in_mobile]["Regimen"].items():
                    print(i[0]," : ",i[1])
            else:
                print(".....You don't have membership !!!")
        elif input2 == "2":
            in_mobile1 = input("Enter mobile no. : ")
            if in_mobile1 in super_user.member_details:
                print("Full Name : ",super_user.member_details[in_mobile1]["Full Name"])
                print("Age : ",super_user.member_details[in_mobile1]["Age"])
                print("Mobile Number : ",  super_user.member_details[in_mobile1]["Mobile Number"])
                print("BMI : ",super_user.member_details[in_mobile1]["BMI"])
            else:
                print(".....You don't have membership !!!")
                self.member_portal()
        elif input2 == "0":
            self.home()
        self.member_portal()     

    
    
sam = super_user()
